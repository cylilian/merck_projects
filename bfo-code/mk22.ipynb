# %%
#!pip install jmp
# !pip install jax
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 MB 15.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.8/736.8 kB 13.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import jmp

# Replace 'your_file.jmp' with the path to your JMP file
dt = jmp.open('data/mk2214.jmp')

# Now you can work with the data table 'dt'
print(dt)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import jmp
#       3 # Replace 'your_file.jmp' with the path to your JMP file
#       4 dt = jmp.open('data/mk2214.jmp')
#
# File ~/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages/jmp/__init__.py:17
#       1 # Copyright 2020 DeepMind Technologies Limited. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """JMP is a Mixed Precision library for JAX."""
# ---> 17 from jmp._src.loss_scale import all_finite
#      18 from jmp._src.loss_scale import DynamicLossScale
#      19 from jmp._src.loss_scale import LossScale
#
# ...
