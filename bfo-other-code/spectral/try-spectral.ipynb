# %%
# !pip install mogptk
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/mogptk/
# Collecting mogptk
#   Downloading mogptk-0.5.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib>=3.3 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (3.8.0)
# Requirement already satisfied: numpy>=1.10 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (1.26.4)
# Requirement already satisfied: pandas in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (2.2.1)
# Requirement already satisfied: python-dateutil in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (2.8.2)
# Requirement already satisfied: scipy>=1.7 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (1.11.4)
# Requirement already satisfied: torch>=1.11 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (2.2.2)
# Requirement already satisfied: ipython in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from mogptk) (8.22.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from matplotlib>=3.3->mogptk) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from python-dateutil->mogptk) (1.16.0)
# Requirement already satisfied: filelock in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (4.10.0)
# Requirement already satisfied: sympy in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (1.12)
# Requirement already satisfied: networkx in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (3.1.3)
# Requirement already satisfied: fsspec in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from torch>=1.11->mogptk) (2024.3.1)
# Requirement already satisfied: decorator in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (2.17.2)
# Requirement already satisfied: stack-data in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (5.14.2)
# Requirement already satisfied: exceptiongroup in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from ipython->mogptk) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from pandas->mogptk) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from pandas->mogptk) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from jedi>=0.16->ipython->mogptk) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from pexpect>4.3->ipython->mogptk) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->mogptk) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from jinja2->torch>=1.11->mogptk) (2.1.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from stack-data->ipython->mogptk) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from stack-data->ipython->mogptk) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from stack-data->ipython->mogptk) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/chenya68/anaconda3/envs/local-gp-mac-no-tf/lib/python3.10/site-packages (from sympy->torch>=1.11->mogptk) (1.3.0)
# Downloading mogptk-0.5.2-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 9.8 kB/s eta 0:00:00a 0:00:01m
# Installing collected packages: mogptk
# Successfully installed mogptk-0.5.2

# %%
#https://games-uchile.github.io/mogptk/examples.html?q=00_Quick_Start
import numpy as np
import torch
import mogptk

torch.manual_seed(1);

# %%
# create time array
n_points = 100
t = np.linspace(0.0, 6.0, n_points)

# channel 1
y1 = np.sin(6.0*t) + 0.2*np.random.normal(size=len(t))

# channel 2, phased version
y2 = np.sin(6.0*t + 2.0) + 0.2*np.random.normal(size=len(t))

# channel 3, added sinosoidal
y3 = np.sin(6.0*t) - np.sin(4.0*t) + 0.2*np.random.normal(size=len(t))

# channel 4, delayed and amplified
y4 = 3.0*np.sin(6.0 * (t-2.0)) + 0.3*np.random.normal(size=len(t))

# %%
# create dataset
dataset = mogptk.DataSet(
    mogptk.Data(t, y1, name='First channel'),
    mogptk.Data(t, y2, name='Second channel'),
    mogptk.Data(t, y3, name='Third channel'),
    mogptk.Data(t, y4, name='Fourth channel')
)

# %%
# remove 40% randomly
for data in dataset:
    data.remove_randomly(pct=0.4)

# remove second half of the first channel
dataset[0].remove_range(start=2.0)
