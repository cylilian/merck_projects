# %% [markdown]
# Import necessary modules

# %%
from gpplus.models import GP_Plus
from gpplus.test_functions.multi_fidelity import multi_fidelity_wing
from gpplus.preprocessing import train_test_split_normalizeX
from gpplus.utils import set_seed

# %% [markdown]
# Data generation and prepration:The next step is to generate the data, standardize it and separate it to train-test sets.Here, we have 4 different sources and 'num' illustrates the number of samples from each of the sources.
#
# To make the problem more challenging, we also add Gaussian noise to the sources with the corresponding standard deviation defined in 'noise_std'.
#
# Then, we generate the data, standardize them and use 1% of that as the train and the rest for test.

# %%
# Set parameters and generate data
set_seed(4)
qual_index = {10: 4}
num = {'0': 5000, '1': 10000, '2': 10000, '3': 10000}
noise_std = {'0': 0.5, '1': 1.0, '2': 1.5, '3': 2.0}
X, y = multi_fidelity_wing(n=num, noise_std=noise_std, random_state=4)

# Split and normalize data
Xtrain, Xtest, ytrain, ytest = train_test_split_normalizeX(X, y, test_size=0.99, qual_index_val=qual_index, stratify=X[..., list(qual_index.keys())])

# %% [markdown]
# Create and fit the GP+ model: Firstly, we create the model using GP_Plus command, and then the model is optimized with model.fit.
#
# Due to the multi-fidelity nature of this example, we set 'multiple_noise=True' to estimate separate noise process for each data source. Additionally, to improve the accuracy of the trained model we use multiple constant base as the mean of the model ('base='multiple_constant')

# %%
model = GP_Plus(Xtrain, ytrain, qual_ind_lev=qual_index, multiple_noise=True, base='multiple_constant')
model.fit(n_jobs=-1)
# Out:
# ## Learning the model's parameters has started ##
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /Users/chenya68/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-07 to the diagonal
#   warnings.warn(
# ## Learning the model's parameters is successfully finished ##

# %% [markdown]
# Visualization and evaluation: As this is a multi-fidelity problem, we use the 'model.visualize_latent(type='MF')' to visualize the global correlation among fidelity sources (their learned manifold).
#
# Then, the accuarcy of the model is evaluated using 'model.evaluation()' command.

# %%
model.evaluation(Xtest, ytest)
model.visualize_latent(type='MF')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.evaluation(Xtest, ytest)
#       2 model.visualize_latent(type='MF')
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpplus/models/gp_plus.py:838, in GP_Plus.evaluation(self, Xtest, ytest)
#     835 ytest_sc = (ytest-self.y_mean)/self.y_std
#     837 with torch.no_grad():
# --> 838     trained_pred_dist = likelihood(self(Xtest))
#     839 # Negative Log Predictive Density (NLPD)
#     840 final_nlpd = gpytorch.metrics.negative_log_predictive_density(trained_pred_dist,ytest_sc)
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/likelihoods/likelihood.py:298, in Likelihood.__call__(self, input, *args, **kwargs)
#     287 # Marginal
#     288 elif any(
#     289     [
#     290         isinstance(input, MultivariateNormal),
#    (...)
#     296     ]
#     297 ):
# --> 298     return self.marginal(input, *args, **kwargs)
#     299 # Error
#     300 else:
#     301     raise RuntimeError(
#     302         "Likelihoods expects a MultivariateNormal or Normal input to make marginal predictions, or a "
#     303         "torch.Tensor for conditional predictions. Got a {}".format(input.__class__.__name__)
#     304     )
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpplus/likelihoods_noise/multifidelity.py:52, in Multifidelity_likelihood.marginal(self, function_dist, *params, **kwargs)
#      50 mean, covar = function_dist.mean, function_dist.lazy_covariance_matrix
#      51 noise_covar = self._shaped_noise_covar(mean.shape, *params, **kwargs)
# ---> 52 full_covar = covar + noise_covar
#      53 return function_dist.__class__(mean, full_covar)
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/lazy/sum_lazy_tensor.py:75, in SumLazyTensor.__add__(self, other)
#      73     return self
#      74 elif isinstance(other, DiagLazyTensor):
# ---> 75     return AddedDiagLazyTensor(self, other)
#      76 elif isinstance(other, SumLazyTensor):
#      77     return SumLazyTensor(*(list(self.lazy_tensors) + list(other.lazy_tensors)))
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/lazy/added_diag_lazy_tensor.py:32, in AddedDiagLazyTensor.__init__(self, preconditioner_override, *lazy_tensors)
#      29 if len(lazy_tensors) > 2:
#      30     raise RuntimeError("An AddedDiagLazyTensor can only have two components")
# ---> 32 broadcasting._mul_broadcast_shape(lazy_tensors[0].shape, lazy_tensors[1].shape)
#      34 if isinstance(lazy_tensors[0], DiagLazyTensor) and isinstance(lazy_tensors[1], DiagLazyTensor):
#      35     raise RuntimeError("Trying to lazily add two DiagLazyTensors. Create a single DiagLazyTensor instead.")
#
# File ~/anaconda3/envs/gpplus-py39/lib/python3.9/site-packages/gpytorch/utils/broadcasting.py:20, in _mul_broadcast_shape(error_msg, *shapes)
#      18 if any(size != non_singleton_sizes[0] for size in non_singleton_sizes):
#      19     if error_msg is None:
# ---> 20         raise RuntimeError("Shapes are not broadcastable for mul operation")
#      21     else:
#      22         raise RuntimeError(error_msg)
#
# RuntimeError: Shapes are not broadcastable for mul operation
