# %%
from itertools import product
from mip import Model, xsum, minimize, BINARY

# %%
n = 10  # note there will be exactly 12 jobs (n=10 jobs plus the two 'dummy' ones)

p = [0, 3, 2, 5, 4, 2, 3, 4, 2, 4, 6, 0]

u = [[0, 0], [5, 1], [0, 4], [1, 4], [1, 3], [3, 2], [3, 1], [2, 4],
     [4, 0], [5, 2], [2, 5], [0, 0]]

c = [6, 8]

S = [[0, 1], [0, 2], [0, 3], [1, 4], [1, 5], [2, 9], [2, 10], [3, 8], [4, 6],
     [4, 7], [5, 9], [5, 10], [6, 8], [6, 9], [7, 8], [8, 11], [9, 11], [10, 11]]

(R, J, T) = (range(len(c)), range(len(p)), range(sum(p)))

model = Model()

x = [[model.add_var(name="x({},{})".format(j, t), var_type=BINARY) for t in T] for j in J]

model.objective = xsum(t * x[n + 1][t] for t in T)

for j in J:
    model += xsum(x[j][t] for t in T) == 1

for (r, t) in product(R, T):
    model += (
        xsum(u[j][r] * x[j][t2] for j in J for t2 in range(max(0, t - p[j] + 1), t + 1))
        <= c[r])

for (j, s) in S:
    model += xsum(t * x[s][t] - t * x[j][t] for t in T) >= p[j]

model.optimize()

print("Schedule: ")
for (j, t) in product(J, T):
    if x[j][t].x >= 0.99:
        print("Job {}: begins at t={} and finishes at t={}".format(j, t, t+p[j]))
print("Makespan = {}".format(model.objective_value))
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 28 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 174 small elements
# Coin0506I Presolve 100 (0) rows, 418 (-2) columns and 3850 (-2) elements
# Clp1000I sum of infeasibilities 0.000128282 - average 1.28282e-06, 37 fixed columns
# Coin0506I Presolve 100 (0) rows, 381 (-39) columns and 3648 (-204) elements
# Clp0029I End of values pass after 381 iterations
# Clp0000I Optimal - objective value 14
# Clp0000I Optimal - objective value 14
# Coin0511I After Postsolve, objective 14, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0000I Optimal - objective value 14
# Clp0000I Optimal - objective value 14
# Clp0000I Optimal - objective value 14
# Clp0032I Optimal objective 14 - 0 iterations time 0.032, Idiot 0.03
#
# Starting MIP optimization
# Cgl0003I 37 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 7 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0005I 12 SOS with 373 members
# Cgl0004I processed model has 100 rows, 373 columns (373 integer (373 of which binary)) and 3518 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 3.192%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 15 integers unsatisfied sum - 4.00298
# Cbc0038I Pass   1: suminf.    1.28333 (10) obj. 17 iterations 35
# Cbc0038I Pass   2: suminf.    1.17391 (5) obj. 34 iterations 25
# Cbc0038I Pass   3: suminf.    0.70000 (4) obj. 34 iterations 8
# Cbc0038I Pass   4: suminf.    0.61053 (4) obj. 34 iterations 5
# Cbc0038I Pass   5: suminf.    1.04722 (6) obj. 34 iterations 10
# Cbc0038I Pass   6: suminf.    1.61111 (7) obj. 34 iterations 7
# Cbc0038I Pass   7: suminf.    1.11053 (6) obj. 34 iterations 8
# Cbc0038I Pass   8: suminf.    0.98431 (8) obj. 34 iterations 13
# Cbc0038I Pass   9: suminf.    1.61111 (7) obj. 34 iterations 11
# Cbc0038I Pass  10: suminf.    0.66667 (4) obj. 34 iterations 8
# Cbc0038I Pass  11: suminf.    1.76667 (6) obj. 34 iterations 10
# Cbc0038I Pass  12: suminf.    0.83804 (6) obj. 34 iterations 14
# Cbc0038I Pass  13: suminf.    0.54167 (4) obj. 34 iterations 6
# Cbc0038I Pass  14: suminf.    2.36667 (6) obj. 34 iterations 14
# Cbc0038I Pass  15: suminf.    1.76667 (6) obj. 34 iterations 7
# Cbc0038I Pass  16: suminf.    1.76667 (6) obj. 34 iterations 0
# Cbc0038I Pass  17: suminf.    0.83804 (6) obj. 34 iterations 14
# Cbc0038I Pass  18: suminf.    0.54167 (4) obj. 34 iterations 6
# Cbc0038I Pass  19: suminf.    2.36667 (6) obj. 34 iterations 14
# Cbc0038I Pass  20: suminf.    1.76667 (6) obj. 34 iterations 7
# Cbc0038I Pass  21: suminf.    1.76667 (6) obj. 34 iterations 0
# Cbc0038I Pass  22: suminf.    0.83804 (6) obj. 34 iterations 14
# Cbc0038I Pass  23: suminf.    0.54167 (4) obj. 34 iterations 6
# Cbc0038I Pass  24: suminf.    2.36667 (6) obj. 34 iterations 14
# Cbc0038I Pass  25: suminf.    1.76667 (6) obj. 34 iterations 6
# Cbc0038I Pass  26: suminf.    1.76667 (6) obj. 34 iterations 0
# Cbc0038I Pass  27: suminf.    0.83804 (6) obj. 34 iterations 14
# Cbc0038I Pass  28: suminf.    0.54167 (4) obj. 34 iterations 6
# Cbc0038I Pass  29: suminf.    2.36667 (6) obj. 34 iterations 14
# Cbc0038I Pass  30: suminf.    1.76667 (6) obj. 34 iterations 7
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 344 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 100 rows 373 columns, reduced to 31 rows 15 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Full problem 101 rows 373 columns, reduced to 101 rows 373 columns - too large
# Cbc0038I After 0.08 seconds - Feasibility pump exiting - took 0.01 seconds
# Cbc0031I 29 added rows had average density of 89.172414
# Cbc0013I At root node, 29 cuts changed objective from 14 to 19.535106 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 159 row cuts average 2.9 elements, 5 column cuts (5 active)  in 0.117 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1291 row cuts average 294.2 elements, 0 column cuts (0 active)  in 0.110 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 102 row cuts average 12.3 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 356 row cuts average 11.6 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (OddWheel) - 5 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 617 row cuts average 56.8 elements, 0 column cuts (0 active)  in 0.050 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 581 row cuts average 78.7 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is 1
# Cbc0014I Cut generator 8 (ZeroHalf) - 529 row cuts average 50.1 elements, 0 column cuts (0 active)  in 0.237 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 19.535106 (1.20 seconds)
# Cbc0004I Integer solution of 24 found after 13085 iterations and 14 nodes (1.58 seconds)
# Cbc0038I Full problem 100 rows 373 columns, reduced to 32 rows 15 columns
# Cbc0016I Integer solution of 23 found by strong branching after 13397 iterations and 21 nodes (1.62 seconds)
# Cbc0012I Integer solution of 22 found by DiveCoefficient after 14458 iterations and 30 nodes (1.72 seconds)
# Cbc0010I After 39 nodes, 5 on tree, 22 best solution, best possible 19.535106 (1.91 seconds)
# Cbc0004I Integer solution of 21 found after 16216 iterations and 40 nodes (1.92 seconds)
# Cbc0038I Full problem 100 rows 373 columns, reduced to 62 rows 45 columns
# Cbc0001I Search completed - best objective 21, took 18763 iterations and 50 nodes (2.15 seconds)
# Cbc0032I Strong branching done 118 times (1961 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 11, 1380 variables fixed on reduced cost
# Total time (CPU seconds):       2.12   (Wallclock seconds):       2.17
#
# Schedule:
# Job 0: begins at t=0 and finishes at t=0
# Job 1: begins at t=0 and finishes at t=3
# Job 2: begins at t=9 and finishes at t=11
# Job 3: begins at t=2 and finishes at t=7
# Job 4: begins at t=3 and finishes at t=7
# Job 5: begins at t=7 and finishes at t=9
# Job 6: begins at t=11 and finishes at t=14
# Job 7: begins at t=7 and finishes at t=11
# Job 8: begins at t=14 and finishes at t=16
# Job 9: begins at t=17 and finishes at t=21
# Job 10: begins at t=11 and finishes at t=17
# Job 11: begins at t=21 and finishes at t=21
# Makespan = 21.0
